# %% [markdown]
# ###Hola, cómo están?

# %%
lista = [1, "9", True, 12]

# %%
for i in lista:
  print(i)
# Out:
# 1
# 9
# True
# 12

# %%
type(lista)
# Out:
# list

# %%
len(lista)
# Out:
# 4

# %%
print(1+2)
# Out:
# 3

# %%
lista
# Out:
# [1, '9', True, 12]

# %%
lista.append(10)

# %%
lista
# Out:
# [1, '9', True, 12, 10]

# %%
lista.remove("9")

# %%
lista
# Out:
# [1, True, 12, 10]

# %%
lista.append('9')

# %%
lista
# Out:
# [1, True, 12, 10, '9']

# %%
lista.index(12)
# Out:
# 2

# %%
lista.append("estudiantes")

# %%
lista
# Out:
# [1, True, 12, 10, '9', 'estudiantes']

# %%
lista.index("estudiantes")
# Out:
# 5

# %%
tupla = ("LU", "MA", "MI", "JU", "VI")

# %%
tupla
# Out:
# ('LU', 'MA', 'MI', 'JU', 'VI')

# %%
capitales = {'Chile':'Santiago','España':'Madrid','Sebastian':'algo', 'Rusia':['Moscu', 1, 2 , 3]}

# %%
nombres = ('enzo', 'seba', 'tomas', 'nico')
for nombres print(2)
# Out:
#   File "<ipython-input-5-6cc4f826a323>", line 2
#     for nombres print(2)
#                     ^
# SyntaxError: invalid syntax

# %%
capitales
# Out:
# {'Chile': 'Santiago',
#  'España': 'Madrid',
#  'Rusia': ['Moscu', 1, 2, 3],
#  'Sebastian': 'algo'}

# %%
for key in capitales:
  print(key, ":", capitales[key])
# Out:
# Chile : Santiago
# España : Madrid
# Sebastian : algo
# Rusia : ['Moscu', 1, 2, 3]

# %%
print(capitales['Rusia'][2])
# Out:
# 2

# %%
dic = dict(nombre="nestor", apellido="Fernandez", edad=22)

# %%
dic
# Out:
# {'apellido': 'Fernandez', 'edad': 22, 'nombre': 'nestor'}

# %%
dic.keys()
# Out:
# dict_keys(['nombre', 'apellido', 'edad'])

# %%
dic.values()
# Out:
# dict_values(['nestor', 'Fernandez', 22])

# %%
15 / 2
# Out:
# 7.5

# %%
15 // 2
# Out:
# 7

# %%
15 % 2
# Out:
# 1

# %%
if 1>3:
  print("es mayor")
elif 1<-1:
  print("es menor")
else:
  print("no sabemos")
# Out:
# no sabemos

# %%
print("Hola Sebas")
# Out:
# Hola Sebas

# %%
tareas = ["desayuno", "limpieza", "almuerzo"] # lista de tareas a realizar

# %%
tareas.append("compras") #agrego un valor a la lista

# %%
tareas
# Out:
# ['desayuno', 'limpieza', 'almuerzo', 'compras']

# %%
nombre = ["Sebastian", "Nahuel", "Carolina", "Joaquin", "Sandra", "Vanina"]

# %%
print(nombre)
# Out:
# ['Sebastian', 'Nahuel', 'Carolina', 'Joaquin', 'Sandra', 'Vanina']

# %%
nombre.remove("Nahuel")

# %%
nombre
# Out:
# ['Sebastian', 'Carolina', 'Joaquin', 'Sandra', 'Vanina']

# %%
nombre[2]
# Out:
# 'Joaquin'

# %%
nombre[4]
# Out:
# 'Vanina'

# %%
for n in nombre:
  print(n)
# Out:
# Sebastian
# Carolina
# Joaquin
# Sandra
# Vanina

# %%
len(nombre)
# Out:
# 5

# %%
nombre[2]

# %%
nombre[4]
# Out:
# 'Vanina'

# %%
num = int(input("Escribi un numero positivo: "))

if num < 0:
  print("Te pedí un numero postivo")
else:
  print("Tu número es el ", num)
# Out:
# Escribi un numero positivo: 3
# Tu número es el  3

# %%
letra = input("Escribi una letra: ")
if letra == "A":
  print("Tu letra es ", letra)
else:
  print("Tu letra no es A ")
# Out:
# Escribi una letra: A
# Tu letra es  A

# %%
# Le pido al usuario que ingrese su edad y lo convierto en INT
edad = int(input("Cuál es tu edad?"))

# evaluo que edad sea menor que 18
if edad < 18:
  print("Sos menor de edad.")
else: # sino cumple, hago esto
  print("Sos mayor de edad.")

# saludo
print("Chau")
# Out:
# Cuál es tu edad?18
# Sos mayor de edad.
# Chau

# %%
for x in range(0, 6):
  print(x)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
count = 0

while count <= 5:
  print(count)
  count += 1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
  nro_1=float(input("Escriba un número: ")) 
  nro_2=float(input("Escriba un número: ")) 

  if nro_1 > nro_2:
    print("Es menor")
  else: 
      print("Es mayor")
# Out:
# Escriba un número: 1
# Escriba un número: 2
# Es mayor

# %%
print("Hola Mundo")

# %%
input("Escribi algo: ")

# %%
n1 = float(input("Escribi un numero:" ))
n2 = float(input("Escribi otro numero:" ))

if n1 > n2:
    print("Este n1 es mayor")

elif n1 < n2:
    print("n2 es mayor")

elif n1 == n2:
    print("son iguales")

else:
    print("no cumple ninguna de las condiciones")
# Out:
# Escribi un numero:2
# Escribi otro numero:6
# n2 es mayor
